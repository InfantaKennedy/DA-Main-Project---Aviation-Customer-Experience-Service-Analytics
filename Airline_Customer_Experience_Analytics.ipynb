# %% [markdown]
# # **Project Title**
#
#
# ## **Aviation Customer Experience & Service Analytics**

# %% [markdown]
# # **Objective(Problem statment)**
#
# 1.   To identify meaningful patterns, trends, and insights in airline customer reviews using Exploratory Data Analysis (EDA).
#
# 2.   To clean, transform, and preprocess airline review data for reliable analysis.
#
# 1.   To analyze customer satisfaction based on overall ratings, service ratings, traveller types, seat types, airlines, and recommendation status.
# 2.   To identify which airline service areas such as seat comfort, cabin staff service, food and beverages, ground service, Wi-Fi connectivity, and in-flight entertainment contribute to customer experience.
#
# 1.   To create meaningful visualizations that clearly communicate trends and customer experience patterns.
# 2.   To provide actionable insights and recommendations that can help understand areas of strong and weak airline service performance.

# %% [markdown]
# ## **Outcome**
#
# The project will provide insights into airline customer satisfaction, service performance, recommendation patterns, and trends over time. The final analysis will provide evidence-based insights that can support better understanding of customer satisfaction and airline service performance.

# %% [markdown]
# ## **Domain**
#
# Aviation / Airline Customer Experience

# %% [markdown]
# ## **Dataset Information**
#
#
# **Dataset:** Skytrax Airline Review Data
#
# **Original Source:** [Mendeley Data – Airline Travel Reviews Data (Skytrax)](https://data.mendeley.com/datasets/vgjk58vf8h/1)
#
# **Original Dataset:** 64,740 rows × 19 columns
#
# **Original Timeline:** 2015–2025
#
# **Dataset Used for Analysis:** 21,984 rows × 19 columns
#
# **Analysis Period:** 2021–2025
#
# **Format:** CSV
#
# The original Skytrax Airline Review Data contains 64,740 airline reviews covering 2015–2025. For this project, the dataset was filtered to include only reviews from 2021–2025, resulting in a working dataset of 21,984 records and 19 columns. The filtered dataset is stored in CSV format and is used for Python-based data cleaning, EDA, visualization, and subsequent Power BI analysis.
#
# **Dataset Column / Features Description:**
# - review_date – Date when the review was posted.
# - over_all_rating – Overall customer rating from 1–10.
# - review_header – Title of the customer review.
# - trip_verified – Indicates whether the review is verified.
# - review_text – Detailed customer feedback.
# - aircraft – Aircraft information; will be removed due to high - missing values and inconsistent entries.
# - type_of_traveller – Category of traveller.
# - seat_type – Class/type of seat used.
# - route – Flight travel route.
# - date_flown – Date or period of the flight.
# - seat_comfort – Rating for seat comfort.
# - cabin_staff_service – Rating for cabin staff service.
# - food__beverages – Rating for food and beverages.
# - inflight_entertainment – Rating for in-flight entertainment.
# - ground_service – Rating for ground services.
# - wifi__connectivity – Rating for Wi-Fi/connectivity.
# - value_for_money – Rating for value for money.
# - recommended – Whether the customer recommends the airline.
# - airline_name – Name of the reviewed airline.

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
#
# * **Business Problem and Expected Outcome**
#
# The objective is to analyze airline customer reviews to understand customer satisfaction and identify the key service areas that influence the overall airline experience.
#
# The analysis will help identify trends in customer ratings, service performance, and recommendation patterns, and provide insights into areas where airline services can be improved.
#
# * **Dataset Selection**
#
# The Skytrax Airline Review Data is selected for this project. It contains 64,740 airline customer reviews with 19 features, covering the period 2015–2025.
#
# For this analysis, the 2021–2025 records will be considered to focus on recent customer experiences. The filtered working dataset contains 21,984 reviews and 19 columns. The dataset includes overall ratings, service ratings, traveller information, seat type, recommendation status, airline name, and customer review text.
#
# * **Source:** [Mendeley Data – Airline Travel Reviews Data (Skytrax)](https://data.mendeley.com/datasets/vgjk58vf8h/1)

# %% [markdown]
# * **Importing libraries and loading dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
url = "https://raw.githubusercontent.com/InfantaKennedy/DA-Main-Project---Aviation-Customer-Experience-Service-Analytics/refs/heads/main/Skytrax%20Airline%20Review%20Data(2021-2025)%20-%20Raw%20File.csv"

df = pd.read_csv(url)

# %% [markdown]
# * ## Initial EDA

# %%
# Dataset Preview:

df.head()
# Out:
#   review_date  over_all_rating                         review_header  \
# 0  2025-08-04                1  "showed zero empathy for passengers"
# 1  2025-07-21                2              "Extremely dissatisfied"
# 2  2025-04-19                2                 "Very bad experience"
# 3  2025-03-12                1            “What a difficult airline”
# 4  2025-03-02                2               “Poor chaotic boarding”
#
#    trip_verified                                        review_text  \
# 0  Trip Verified   My afternoon flight was delayed and eventuall...
# 1  Trip Verified   The flight was postponed 3 times with insuffi...
# 2  Trip Verified   They will charge you for your hand baggage if...
# 3  Trip Verified   The flight was delayed from 15:20 to 16:25. I...
# 4  Trip Verified   No crowd control and boarding was like cattle...
#
#      aircraft type_of_traveller      seat_type  \
# 0         NaN          business  economy_class
# ...

# %%
# Dataset Dimensions

df.shape
# Out:
# (21984, 19)

# %%
# Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21984 entries, 0 to 21983
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   review_date             21984 non-null  object
#  1   over_all_rating         21984 non-null  int64
#  2   review_header           21984 non-null  object
#  3   trip_verified           21957 non-null  object
#  4   review_text             21871 non-null  object
#  5   aircraft                6932 non-null   object
#  6   type_of_traveller       21981 non-null  object
#  7   seat_type               21983 non-null  object
#  8   route                   21810 non-null  object
#  9   date_flown              21981 non-null  object
#  10  seat_comfort            20230 non-null  float64
#  11  cabin_staff_service     20070 non-null  float64
#  12  food__beverages         16368 non-null  float64
#  13  inflight_entertainment  13828 non-null  float64
# ...

# %%
# Descriptive Statistics

df.describe()
# Out:
#        over_all_rating  seat_comfort  cabin_staff_service  food__beverages  \
# count     21984.000000  20230.000000         20070.000000     16368.000000
# mean          3.295306      2.496639             2.745740         2.450513
# std           3.205475      1.444052             1.592647         1.493349
# min           1.000000      1.000000             1.000000         1.000000
# 25%           1.000000      1.000000             1.000000         1.000000
# 50%           1.000000      2.000000             3.000000         2.000000
# 75%           5.000000      4.000000             4.000000         4.000000
# max          10.000000      5.000000             5.000000         5.000000
#
#        inflight_entertainment  ground_service  wifi__connectivity  \
# count            13828.000000    20975.000000        10568.000000
# mean                 2.491611        2.194136            2.066616
# std                  1.497183        1.559712            1.452347
# ...

# %%
# Missing Value Check

df.isnull().sum()
# Out:
# review_date                   0
# over_all_rating               0
# review_header                 0
# trip_verified                27
# review_text                 113
# aircraft                  15052
# type_of_traveller             3
# seat_type                     1
# route                       174
# date_flown                    3
# seat_comfort               1754
# cabin_staff_service        1914
# food__beverages            5616
# inflight_entertainment     8156
# ground_service             1009
# wifi__connectivity        11416
# value_for_money               2
# recommended                   1
# airline_name                  0
# dtype: int64

# %%
# Duplicate Record Check

df.duplicated().sum()
# Out:
# np.int64(0)
